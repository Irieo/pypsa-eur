# %%
import geopandas

# %%
g = geopandas.read_file("../resources/country_shapes.geojson")

# %%
g.plot()
# Out:
# <AxesSubplot:>

# %%
r = geopandas.read_file("../resources/regions_onshore.geojson")

# %%
r.plot()
# Out:
# <AxesSubplot:>
